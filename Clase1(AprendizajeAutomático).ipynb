# %% [markdown]
# <a href="https://colab.research.google.com/github/Nickyyyy99/Aprendizaje_Automatico1/blob/main/Clase1(AprendizajeAutom%C3%A1tico).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎯 **Unidad 1 Carga de DataSet** (importación y exploración)
#
# 🚀 Flujo de trabajo de la Unidad 1
#
# 1. 📥 Descargar el dataset: usamos wget para traer el archivo .zip desde la web.
#
# 2. 📂 Descomprimirlo: con unzip lo extraemos y obtenemos los archivos de texto.
#
# 3. 🐼 Leerlo en Pandas: con pd.read_csv cargamos los .txt o .csv en un DataFrame.
#
# 4. 👀 Mirar primeras filas: con .head() vemos una muestra para asegurarnos de que se cargó bien.
#
# 5.  📏 Ver dimensiones: con .shape conocemos cuántas filas y columnas tiene el dataset.
#
# 6. 📊 Estadísticas básicas: con .describe() o .info() vemos un resumen general de los datos.

# %%
url = "https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip"

# %%
# 1. Descarga del dataset (sentiment labelled sentences)
# !wget https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip
# Out:
# --2025-08-26 17:56:49--  https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘sentiment+labelled+sentences.zip’
#
# sentiment+labelled+     [ <=>                ]  82.21K  --.-KB/s    in 0.03s
#
# 2025-08-26 17:56:49 (3.20 MB/s) - ‘sentiment+labelled+sentences.zip’ saved [84188]

# %%
# 2. Descomprimir el archivo
# !unzip sentiment+labelled+sentences.zip
# Out:
# Archive:  sentiment+labelled+sentences.zip
#    creating: sentiment labelled sentences/
#   inflating: sentiment labelled sentences/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/sentiment labelled sentences/
#   inflating: __MACOSX/sentiment labelled sentences/._.DS_Store
#   inflating: sentiment labelled sentences/amazon_cells_labelled.txt
#   inflating: sentiment labelled sentences/imdb_labelled.txt
#   inflating: __MACOSX/sentiment labelled sentences/._imdb_labelled.txt
#   inflating: sentiment labelled sentences/readme.txt
#   inflating: __MACOSX/sentiment labelled sentences/._readme.txt
#   inflating: sentiment labelled sentences/yelp_labelled.txt
#   inflating: __MACOSX/._sentiment labelled sentences

# %%
# 3. Ver los archivos extraídos
# !ls
# Out:
#  __MACOSX     'sentiment labelled sentences'
#  sample_data   sentiment+labelled+sentences.zip

# %%
# 4. Importar librería
import pandas as pd

# 5. Cargar dataset de IMDB
dataset = pd.read_csv("sentiment labelled sentences/imdb_labelled.txt",
                      delimiter="\t", header=None)

# 6. Mostrar primeras filas
display(dataset.head())

# 7. Resumen estadístico (aunque para texto aporta poco)
dataset.describe()

# 8. Dimensiones (filas, columnas)
dataset.shape
# Out:
#                                                    0  1
# 0  A very, very, very slow-moving, aimless movie ...  0
# 1  Not sure who was more lost - the flat characte...  0
# 2  Attempting artiness with black & white and cle...  0
# 3       Very little music or anything to speak of.    0
# 4  The best scene in the movie was when Gerardo i...  1
# (748, 2)

# %%
# 9. Cargar dataset de Amazon
amazon_df = pd.read_csv("sentiment labelled sentences/amazon_cells_labelled.txt",
                        delimiter="\t", header=None)
display(amazon_df.head())
# Out:
#                                                    0  1
# 0  So there is no way for me to plug it in here i...  0
# 1                        Good case, Excellent value.  1
# 2                             Great for the jawbone.  1
# 3  Tied to charger for conversations lasting more...  0
# 4                                  The mic is great.  1
